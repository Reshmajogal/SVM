# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=250
import seaborn as sns
sns.set_theme(style='darkgrid',palette='rainbow')
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
df=pd.read_csv('SalaryData_Train(1).csv')
df
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
df.duplicated().sum()
# Out:
# 3258

# %%
df.drop_duplicates()
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 30154   53            Private        Masters           14
# 30155   22            Private   Some-college           10
# 30156   27            Private     Assoc-acdm           12
# 30158   58            Private        HS-grad            9
# 30160   52       Self-emp-inc        HS-grad            9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# ### Explore the categorical variable

# %%
categorical=[i for i in df.columns if df[i].dtype=='object']
print('There are',len(categorical),'categorical variables')
print('The categorical variables are:',categorical)
# Out:
# There are 9 categorical variables
# The categorical variables are: ['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native', 'Salary']

# %% [markdown]
# ### Missing values in categorical variables

# %%
df[categorical].isnull().sum()
# Out:
# workclass        0
# education        0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# native           0
# Salary           0
# dtype: int64

# %% [markdown]
# ### Frequency counts of categorical variables

# %%
for i in categorical:
    
    print(df[i].value_counts())
# Out:
#  Private             22285
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: workclass, dtype: int64
#  HS-grad         9840
#  Some-college    6677
#  Bachelors       5044
#  Masters         1627
#  Assoc-voc       1307
#  11th            1048
#  Assoc-acdm      1008
#  10th             820
#  7th-8th          557
#  Prof-school      542
#  9th              455
#  12th             377
#  Doctorate        375
#  5th-6th          288
#  1st-4th          151
#  Preschool         45
# Name: education, dtype: int64
#  Married-civ-spouse       14065
#  Never-married             9725
#  Divorced                  4214
#  Separated                  939
#  Widowed                    827
#  Married-spouse-absent      370
#  Married-AF-spouse           21
# Name: maritalstatus, dtype: int64
#  Prof-specialty       4038
#  Craft-repair         4030
# ...

# %% [markdown]
# ### Frequency distribution of categorical variables

# %%
for i in categorical:
    print(df[i].value_counts()/(len(df)))
# Out:
#  Private             0.738868
#  Self-emp-not-inc    0.082855
#  Local-gov           0.068532
#  State-gov           0.042406
#  Self-emp-inc        0.035609
#  Federal-gov         0.031266
#  Without-pay         0.000464
# Name: workclass, dtype: float64
#  HS-grad         0.326249
#  Some-college    0.221379
#  Bachelors       0.167236
#  Masters         0.053944
#  Assoc-voc       0.043334
#  11th            0.034747
#  Assoc-acdm      0.033421
#  10th            0.027187
#  7th-8th         0.018468
#  Prof-school     0.017970
#  9th             0.015086
#  12th            0.012500
#  Doctorate       0.012433
#  5th-6th         0.009549
#  1st-4th         0.005006
#  Preschool       0.001492
# Name: education, dtype: float64
#  Married-civ-spouse       0.466331
#  Never-married            0.322436
#  Divorced                 0.139717
#  Separated                0.031133
#  Widowed                  0.027420
#  Married-spouse-absent    0.012267
#  Married-AF-spouse        0.000696
# ...

# %% [markdown]
# ### cardinality

# %%
for i in categorical:
    print('There are', len(df[i].unique()),'no.of unique values in',i)
# Out:
# There are 7 no.of unique values in workclass
# There are 16 no.of unique values in education
# There are 7 no.of unique values in maritalstatus
# There are 14 no.of unique values in occupation
# There are 6 no.of unique values in relationship
# There are 5 no.of unique values in race
# There are 2 no.of unique values in sex
# There are 40 no.of unique values in native
# There are 2 no.of unique values in Salary

# %% [markdown]
# ##### Relationship between numerical columns

# %%
sns.pairplot(df)

# %%
df.head(2)
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
#
#          occupation    relationship    race    sex  capitalgain  capitalloss  \
# 0      Adm-clerical   Not-in-family   White   Male         2174            0
# 1   Exec-managerial         Husband   White   Male            0            0
#
#    hoursperweek          native  Salary
# 0            40   United-States   <=50K
# 1            13   United-States   <=50K

# %% [markdown]
# #### Relationship between categorical columns

# %%
sns.countplot(df['workclass'],hue=df['Salary'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='workclass', ylabel='count'>

# %%
sns.countplot(y=df['education'],hue=df['Salary'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='education'>

# %%
sns.countplot(y=df['maritalstatus'],hue=df['Salary'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='maritalstatus'>

# %%
sns.countplot(df['relationship'],hue=df['Salary'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='relationship', ylabel='count'>

# %%
sns.countplot(df['race'],hue=df['Salary'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
sns.countplot(df['sex'],hue=df['Salary'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(y=df['native'],hue=df['Salary'])
plt.tight_layout()

# %% [markdown]
# #### Checking linear separabiliy od data

# %%
sns.scatterplot(df['hoursperweek'],df['educationno'],hue=df['Salary'],palette='rainbow')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hoursperweek', ylabel='educationno'>

# %% [markdown]
# ###### Give data is not linearly separable

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in categorical:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %% [markdown]
# # Declare feature vector and target variable

# %%
x=df.drop(['Salary'],axis=1)
y=df['Salary']

# %% [markdown]
# # Feature Scalling

# %%
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# # Train & Test Split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # Model Building

# %%
svm=SVC()
svm.fit(xtrain,ytrain)
ypred=svm.predict(xtest)
ypred
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      4464
#            1       0.78      0.55      0.64      1569
#
#     accuracy                           0.84      6033
#    macro avg       0.82      0.75      0.77      6033
# weighted avg       0.84      0.84      0.83      6033

# %%
svm.score(xtrain,ytrain) ,svm.score(xtest,ytest)
# Out:
# (0.8528680371352785, 0.841869716558926)

# %% [markdown]
# # Hyperparameter Tunning

# %%
params={'kernel':['poly','rbf','linear','sigmoid'],
        'C':[0.1,0.001,0.0001,1,10],
        'gamma':[0.1,0.001,1,10]
        }

# %%
sv=GridSearchCV(SVC(),param_grid=params,verbose=-1)

# %%
sv.fit(xtrain,ytrain)

# %%
#sv.best_params_

# %%
# Final Model

# %%
#svm=SVC()
#svm.fit(xtrain,ytrain)
#svm.predict(xtrest)

# %%
#print('Training accuracy:',svm.score(xtrain,ytrain))
#print('Testing accuracy:',svm.score(xtest,ytest))
